# %% [markdown]
# # Healthcare Claims Intelligence — Exploratory Analysis
#
# This notebook walks through the synthetic claims pipeline, cost/utilization patterns, provider peer benchmarking, review-score interpretation, and validation against injected synthetic scenarios.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from claims_intelligence.pipeline import run_pipeline
result = run_pipeline(n_claims=20000, seed=42, project_root=ROOT)

# %% [markdown]
# ## 1. Data quality
# The pipeline checks schema completeness, duplicate claim IDs, monetary consistency, and referential integrity before scoring.

# %%
result['quality']

# %% [markdown]
# ## 2. Highest-priority providers
# Review scores prioritize unusual patterns; they do not establish fraud.

# %%
result['provider_scores'][['provider_id','specialty','review_score','review_reasons','total_allowed']].head(15)

# %% [markdown]
# ## 3. Synthetic validation
# Injected scenario labels are excluded from scoring features and used only to evaluate whether ranking surfaces the intended synthetic patterns.

# %%
result['evaluation']
